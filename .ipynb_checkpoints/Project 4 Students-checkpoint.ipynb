# %% [markdown]
# # [Computational Social Science] Project 4: Unsupervised Learning

# %% [markdown]
# ## Data Description and Preprocessing
#
# For this project, you will explore data from the [National Health and Nutrition Examination Survey](https://www.kaggle.com/cdc/national-health-and-nutrition-examination-survey?select=questionnaire.csv). NHANES is a unique study that combines survey methodology with in-person medical examinations to create a dataset with demographic information, health indicators, and health outcomes.

# %% [markdown]
# We start by importing the data and doing some preliminary preprocessing for you. We import some libraries that will be helpful as well. 'SEQN' is the ID number for each respondent, and 'HSD010' will be our target outcome. [HSD010](https://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/HSQ_H.htm#HSD010) asks for the respondent's self reported health condition, which can range from "excellent" to "poor."

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
sns.set_style("darkgrid")
from sklearn.model_selection import train_test_split

# %%
# Load nhanes data
nhanes = pd.read_csv('nhanes.csv')
# Get the ID numbers for each observation (seqn)
seqn = nhanes['SEQN']
# Get the target, "self-reported health condition," HSD010
hsd010 = nhanes['HSD010']
# Drop SEQN from the dataframe and then apply the standard scaler
nhanes = nhanes.drop(['SEQN', 'HSD010'], axis = 1)
nhanes_scaled = pd.DataFrame(StandardScaler().fit_transform(nhanes),
                             columns = nhanes.columns)
# Add the ID and target back in
nhanes_scaled['SEQN'] = seqn
nhanes_scaled['HSD010'] = hsd010
nhanes_scaled = nhanes_scaled.set_index('SEQN')
nhanes_scaled.head()
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ770    OHQ845   PAAQUEX  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ...  0.383802 -0.646584 -0.484200
# 73576 -0.057306  0.128246  0.080373  ...  0.383802 -1.539259 -0.484200
# 73579 -0.057306  0.128246 -0.189513  ...  0.383802 -1.539259  2.065262
# 73581 -0.057306  0.128246  0.080373  ...  0.383802 -0.646584 -0.484200
# 73584 -0.057306  0.128246  0.080373  ... -2.605509  0.246091  2.065262
#
#          SMQ860  SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x  HSD010
# SEQN
# 73568  1.125008     0.0 -2.081666  1.087115  1.463404   0.612440       1
# 73576  1.125008     0.0 -2.081666  1.087115 -0.683338  -1.632812       1
# 73579 -0.888883     0.0  0.480384 -0.919866 -0.683338  -1.632812       2
# 73581  1.125008     0.0  0.480384 -0.919866 -0.683338   0.612440       2
# 73584  1.125008     0.0  0.480384 -0.919866  1.463404  -1.632812       3
#
# [5 rows x 242 columns]

# %% [markdown]
# ## Plots

# %% [markdown]
# Let's take a look at the data. Below we visualize boxplots of family income to federal poverty line ratio ('INDFMPIR') and self-reported health condition. Notice how there are some clear patterns (the lower the ratio, the lower reported health condition), but it's not a perfect separation. We have 240+ features in our dataset, and we likely have several features in our dataset that highly correlate with our family income-poverty line ratio measure - PCA will help us simplify these.

# %%
# Create a binary version of hsd010 where 1-3 are "good" and 4-5 are "poor"
nhanes_scaled['HSD010_binary'] = hsd010_binary = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['good', 'good', 'good', 'poor', 'poor']) 
# Recode the original hsd010 with the string labels
nhanes_scaled['HSD010'] = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['excellent', 'very good', 'good', 'fair', 'poor'])
# Boxplot of hsd010
ax = sns.boxplot(x = 'HSD010', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Self-Reported Health Status")
plt.show()

# %%
# Boxplot of hsd010_binary
ax = sns.boxplot(x = 'HSD010_binary', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Binary Self-Reported Health Status")
plt.show()

# %% [markdown]
# Family income also is not necessarily well correlated with measured health outcomes. See below where we look at the relationship between Body Mass Index (BMI) and the family income-poverty line ratio, and shade points by self-reported health condition. It's hard to find a clear pattern - this is where clustering may come in handy.

# %%
ax = sns.scatterplot(x = "INDFMPIR", y = "BMXBMI", hue = "HSD010", palette = "tab10", data = nhanes_scaled)
ax.set(xlabel = "Income to Poverty Line Ratio",
      ylabel = "Body Mass Index")
ax.set_title("BMI v. Income-Poverty Ratio")
plt.show()

# %% [markdown]
# Before we move to working on unsupervised methods, we'll drop our target variables again:

# %%
nhanes_scaled = nhanes_scaled.drop(['HSD010', 'HSD010_binary'], axis = 1)

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# Conduct a Principal Component Analysis (PCA) of the nhanes data. The data has already been prepared for you, so you can work directly on nhanes_scaled. Be sure to do the following:
#
# - Choose the number of components and provide 1-2 sentences about your choice of the number of components.
# - Plot a barplot of the variation explains by each component.
# - Choose how many components you will use to fit a supervised learning model and provide 1-2 sentences to explain that choice.
# - Plot a 2D scatterplot of the first two components and provide 1-2 sentences analyzing the plot.

# %% [markdown]
# ### Train PCA and Discuss Number of Components

# %%
X = nhanes_scaled

# %%
## Your Answer Here
pca = PCA(n_components=2)
principalComponents_nhanes = pca.fit_transform(X)

# %%
nhanes_scaled.head()
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ033    OHQ770    OHQ845  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ... -0.680203  0.383802 -0.646584
# 73576 -0.057306  0.128246  0.080373  ... -0.680203  0.383802 -1.539259
# 73579 -0.057306  0.128246 -0.189513  ... -0.680203  0.383802 -1.539259
# 73581 -0.057306  0.128246  0.080373  ... -0.680203  0.383802 -0.646584
# 73584 -0.057306  0.128246  0.080373  ... -0.680203 -2.605509  0.246091
#
#         PAAQUEX    SMQ860  SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x
# SEQN
# 73568 -0.484200  1.125008     0.0 -2.081666  1.087115  1.463404   0.612440
# 73576 -0.484200  1.125008     0.0 -2.081666  1.087115 -0.683338  -1.632812
# 73579  2.065262 -0.888883     0.0  0.480384 -0.919866 -0.683338  -1.632812
# 73581 -0.484200  1.125008     0.0  0.480384 -0.919866 -0.683338   0.612440
# 73584  2.065262  1.125008     0.0  0.480384 -0.919866  1.463404  -1.632812
#
# [5 rows x 241 columns]

# %% [markdown]
# ### Barplot of Components

# %%
## Your Answer Here
pca_df = pd.DataFrame(data = principalComponents_nhanes
             , columns = ['principal component 1', 'principal component 2'])
pca_df.head()
# Out:
#    principal component 1  principal component 2
# 0               9.527812              -0.816217
# 1              -5.838338              -3.692567
# 2              -0.719455              -2.573203
# 3               3.533627              -2.576983
# 4              -6.872094              -4.194240

# %%
plt.figure()
plt.figure(figsize=(10,10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.xlabel('Principal Component - 1',fontsize=20)
plt.ylabel('Principal Component - 2',fontsize=20)
plt.title("Principal Component Analysis of NHANES Dataset",fontsize=20)


targets = ['good', 'poor']
colors = ['r', 'g']
for target, color in zip(targets,colors):
    indicesToKeep = nhanes_scaled['HSD010_binary'] == targets
    plt.scatter(pca_df.loc[indicesToKeep, 'principal component 1']
               , pca_df.loc[indicesToKeep, 'principal component 2'], c = color, s = 50)

plt.legend(targets,prop={'size': 15})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HSD010_binary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-e0c3fd8aef24> in <module>
#      11 colors = ['r', 'g']
#      12 for target, color in zip(targets,colors):
# ---> 13     indicesToKeep = nhanes_scaled['HSD010_binary'] == targets
#      14     plt.scatter(pca_df.loc[indicesToKeep, 'principal component 1']
#      15                , pca_df.loc[indicesToKeep, 'principal component 2'], c = color, s = 50)
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'HSD010_binary'

# %% [markdown]
# ### How many components will you use to fit a supervised learning model?

# %%
## Your Answer Here

# %% [markdown]
# ### 2D Scatterplot of the first two components

# %%
## Your Answer Here

# %% [markdown]
# ## K-Means

# %% [markdown]
# - Choose a clustering algorithm and explain it in 1-2 sentences.
# - Cluster the nhanes data. Detail any choice you need to make with regards to number of clusters, and how you arrived at that choice. For instance, you might use the [elbow method](https://en.wikipedia.org/wiki/Elbow_method_(clustering) if you choose k-means.
# - Plot your clusters on top of BMI v. Income Poverty Ratio Plot. Describe what you see in 1-2 sentences.
# - Retrain the clustering algorithm, but this time use your PCA results instead of the original dataframe. Plot the clusters on top of the 2D PCA scatterplot from the previous step. Describe your results in 1-2 sentences.

# %% [markdown]
# ### Choose a Clustering Algorithm

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# ### Cluster nhanes

# %%
np.random.seed(10)

# Elbow Method
sse = {}
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, max_iter=300).fit(nhanes_scaled)
    nhanes_scaled["clusters"] = kmeans.labels_
    sse[k] = kmeans.inertia_ # Inertia: Sum of distances of samples to their closest cluster center
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of clusters")
plt.ylabel("SSE")
plt.show()

# %%
# Silhouette Coefficient
from sklearn.metrics import silhouette_score

for n_cluster in range(2, 11):
    kmeans = KMeans(n_clusters=n_cluster).fit(nhanes_scaled)
    label = kmeans.labels_
    sil_coeff = silhouette_score(nhanes_scaled, label, metric='euclidean')
    print("For n_clusters={}, The Silhouette Coefficient is {}".format(n_cluster, sil_coeff))
# Out:
# For n_clusters=2, The Silhouette Coefficient is 0.08499873957430466
# For n_clusters=3, The Silhouette Coefficient is 0.09159984821921215
# For n_clusters=4, The Silhouette Coefficient is 0.033694008130643466
# For n_clusters=5, The Silhouette Coefficient is 0.035978126511861094
# For n_clusters=6, The Silhouette Coefficient is 0.034362936962607345
# For n_clusters=7, The Silhouette Coefficient is 0.027785695567170317
# For n_clusters=8, The Silhouette Coefficient is 0.025575062506601468
# For n_clusters=9, The Silhouette Coefficient is 0.027027895172073747
# For n_clusters=10, The Silhouette Coefficient is 0.023106660221695437

# %%
# Choose 3 clusters
kmeans = KMeans(n_clusters=3,
               max_iter=300 #default
               ).fit(nhanes_scaled)

# %%
print("Centers")
print(kmeans.cluster_centers_)
print()

print("Labels")
print(kmeans.labels_)
print()

for point, label in zip(nhanes_scaled, kmeans.labels_):
    print("Coordinates:", point, "Label:", label)
# Out:
# Centers
# [[ 0.00000000e+00  6.78768991e-03  0.00000000e+00 -2.93473512e-02
#   -5.28600635e-02  3.80268172e-02 -2.04280822e-02 -1.55674085e-02
#   -8.25164331e-03  2.70152614e-02 -5.92370852e-03  3.99213924e-02
#    3.00984106e-02 -2.27604426e-01 -4.34410475e-01 -3.76489501e-01
# Coordinates: DR1MNRSP Label: 1
# Coordinates: DR1HELPD Label: 0
# Coordinates: DBQ095Z Label: 2
# Coordinates: DRQSPREP Label: 1
# Coordinates: DR1STY Label: 0
# Coordinates: DRQSDIET Label: 2
# Coordinates: DR1TNUMF Label: 0
# Coordinates: DR1TKCAL Label: 0
# Coordinates: DR1TPROT Label: 1
# Coordinates: DR1TCARB Label: 1
# Coordinates: DR1TSUGR Label: 0
# Coordinates: DR1TFIBE Label: 2
# Coordinates: DR1TTFAT Label: 2
# Coordinates: DR1TSFAT Label: 0
# Coordinates: DR1TMFAT Label: 0
# Coordinates: DR1TPFAT Label: 2
# Coordinates: DR1TCHOL Label: 0
# Coordinates: DR1TATOC Label: 0
# Coordinates: DR1TRET Label: 0
# Coordinates: DR1TVARA Label: 0
# Coordinates: DR1TBCAR Label: 2
# Coordinates: DR1TLZ Label: 2
# Coordinates: DR1TVB1 Label: 1
# Coordinates: DR1TVB2 Label: 1
# Coordinates: DR1TNIAC Label: 2
# Coordinates: DR1TVB6 Label: 2
# Coordinates: DR1TFOLA Label: 0
# Coordinates: DR1TFA Label: 0
# Coordinates: DR1TFF Label: 2
# Coordinates: DR1TFDFE Label: 2
# Coordinates: DR1TCHL Label: 0
# Coordinates: DR1TVB12 Label: 0
# Coordinates: DR1TVC Label: 0
# Coordinates: DR1TVD Label: 1
# Coordinates: DR1TVK Label: 0
# Coordinates: DR1TCALC Label: 2
# Coordinates: DR1TPHOS Label: 0
# Coordinates: DR1TMAGN Label: 0
# Coordinates: DR1TIRON Label: 2
# Coordinates: DR1TZINC Label: 0
# Coordinates: DR1TCOPP Label: 0
# Coordinates: DR1TSODI Label: 2
# Coordinates: DR1TPOTA Label: 0
# Coordinates: DR1TSELE Label: 0
# Coordinates: DR1TMOIS Label: 0
# Coordinates: DR1TS040 Label: 2
# Coordinates: DR1TS060 Label: 1
# Coordinates: DR1TS080 Label: 0
# Coordinates: DR1TS100 Label: 1
# Coordinates: DR1TS120 Label: 0
# Coordinates: DR1TS140 Label: 2
# Coordinates: DR1TS160 Label: 0
# Coordinates: DR1TS180 Label: 1
# Coordinates: DR1TM161 Label: 0
# Coordinates: DR1TM181 Label: 0
# Coordinates: DR1TM201 Label: 2
# Coordinates: DR1TP182 Label: 1
# Coordinates: DR1TP183 Label: 2
# Coordinates: DR1TP204 Label: 0
# Coordinates: DR1.300 Label: 2
# Coordinates: DR1TWS Label: 2
# Coordinates: DRD340 Label: 0
# Coordinates: DRD360 Label: 2
# Coordinates: PEASCST1 Label: 1
# Coordinates: PEASCTM1 Label: 2
# Coordinates: BPXPULS Label: 2
# Coordinates: BMDSTATS Label: 0
# Coordinates: BMXWT Label: 0
# Coordinates: BMXHT Label: 2
# Coordinates: BMXBMI Label: 0
# Coordinates: BMXARML Label: 0
# Coordinates: BMXARMC Label: 0
# Coordinates: BMXWAIST Label: 0
# Coordinates: MGDEXSTS Label: 2
# Coordinates: OHDEXSTS Label: 0
# Coordinates: OHDDESTS Label: 0
# Coordinates: OHX01TC Label: 2
# Coordinates: OHX02TC Label: 0
# Coordinates: OHX03TC Label: 0
# Coordinates: OHX04TC Label: 1
# Coordinates: OHX05TC Label: 0
# Coordinates: OHX06TC Label: 0
# Coordinates: OHX07TC Label: 2
# Coordinates: OHX08TC Label: 0
# Coordinates: OHX09TC Label: 2
# Coordinates: OHX10TC Label: 0
# Coordinates: OHX11TC Label: 2
# Coordinates: OHX12TC Label: 0
# Coordinates: OHX13TC Label: 2
# Coordinates: OHX14TC Label: 0
# Coordinates: OHX15TC Label: 0
# Coordinates: OHX16TC Label: 1
# Coordinates: OHX17TC Label: 2
# Coordinates: OHX18TC Label: 0
# Coordinates: OHX19TC Label: 0
# Coordinates: OHX20TC Label: 1
# Coordinates: OHX21TC Label: 2
# Coordinates: OHX22TC Label: 2
# Coordinates: OHX23TC Label: 0
# Coordinates: OHX24TC Label: 0
# Coordinates: OHX25TC Label: 0
# Coordinates: OHX26TC Label: 0
# Coordinates: OHX27TC Label: 0
# Coordinates: OHX28TC Label: 0
# Coordinates: OHX29TC Label: 2
# Coordinates: OHX30TC Label: 0
# Coordinates: OHX31TC Label: 1
# Coordinates: OHX32TC Label: 0
# Coordinates: URXUMA Label: 2
# Coordinates: URXUMS Label: 0
# Coordinates: URXUCR.x Label: 0
# Coordinates: URXCRS Label: 2
# Coordinates: URDACT Label: 0
# Coordinates: LBXWBCSI Label: 0
# Coordinates: LBXLYPCT Label: 2
# Coordinates: LBXMOPCT Label: 0
# Coordinates: LBXNEPCT Label: 0
# Coordinates: LBXEOPCT Label: 2
# Coordinates: LBXBAPCT Label: 0
# Coordinates: LBDLYMNO Label: 0
# Coordinates: LBDMONO Label: 0
# Coordinates: LBDNENO Label: 0
# Coordinates: LBXRBCSI Label: 0
# Coordinates: LBXHGB Label: 0
# Coordinates: LBXHCT Label: 0
# Coordinates: LBXMCVSI Label: 0
# Coordinates: LBXMCHSI Label: 1
# Coordinates: LBXMC Label: 1
# Coordinates: LBXRDW Label: 0
# Coordinates: LBXPLTSI Label: 2
# Coordinates: LBXMPSI Label: 2
# Coordinates: PHQ020 Label: 0
# Coordinates: PHQ030 Label: 0
# Coordinates: PHQ040 Label: 2
# Coordinates: PHQ050 Label: 2
# Coordinates: PHQ060 Label: 2
# Coordinates: PHAFSTMN.x Label: 0
# Coordinates: LBXHA Label: 0
# Coordinates: LBXHBS Label: 2
# Coordinates: URXVOL1 Label: 0
# Coordinates: SDDSRVYR Label: 0
# Coordinates: RIDSTATR Label: 0
# Coordinates: RIAGENDR Label: 2
# Coordinates: RIDAGEYR Label: 0
# Coordinates: RIDRETH1 Label: 0
# Coordinates: RIDRETH3 Label: 0
# Coordinates: RIDEXMON Label: 0
# Coordinates: DMDBORN4 Label: 0
# Coordinates: DMDCITZN Label: 2
# Coordinates: SIALANG Label: 2
# Coordinates: SIAPROXY Label: 0
# Coordinates: SIAINTRP Label: 0
# Coordinates: FIALANG Label: 0
# Coordinates: FIAPROXY Label: 2
# Coordinates: FIAINTRP Label: 2
# Coordinates: DMDHHSIZ Label: 0
# Coordinates: DMDFMSIZ Label: 2
# Coordinates: DMDHRGND Label: 0
# Coordinates: DMDHRAGE Label: 1
# Coordinates: DMDHRBR4 Label: 0
# Coordinates: DMDHREDU Label: 0
# Coordinates: DMDHRMAR Label: 2
# Coordinates: WTINT2YR Label: 0
# Coordinates: WTMEC2YR Label: 2
# Coordinates: SDMVPSU Label: 0
# Coordinates: SDMVSTRA Label: 0
# Coordinates: INDHHIN2 Label: 2
# Coordinates: INDFMIN2 Label: 0
# Coordinates: INDFMPIR Label: 0
# Coordinates: CBD070 Label: 0
# Coordinates: HSQ500 Label: 2
# Coordinates: HSQ510 Label: 2
# Coordinates: HSQ520 Label: 0
# Coordinates: HSAQUEX Label: 0
# Coordinates: DIQ010 Label: 0
# Coordinates: DIQ050 Label: 0
# Coordinates: DLQ010 Label: 2
# Coordinates: DLQ020 Label: 0
# Coordinates: DLQ040 Label: 2
# Coordinates: DLQ050 Label: 2
# Coordinates: DLQ060 Label: 0
# Coordinates: FSD032A Label: 0
# Coordinates: FSD032B Label: 0
# Coordinates: FSD032C Label: 0
# Coordinates: FSDHH Label: 2
# Coordinates: FSDAD Label: 0
# Coordinates: FSD151 Label: 1
# Coordinates: FSQ165 Label: 0
# Coordinates: FSQ162 Label: 0
# Coordinates: HEQ010 Label: 1
# Coordinates: HEQ030 Label: 0
# Coordinates: HIQ011 Label: 0
# Coordinates: HIQ270 Label: 2
# Coordinates: HIQ210 Label: 1
# Coordinates: HOD050 Label: 0
# Coordinates: HOQ065 Label: 0
# Coordinates: HUQ010 Label: 0
# Coordinates: HUQ020 Label: 0
# Coordinates: HUQ030 Label: 2
# Coordinates: HUQ041 Label: 2
# Coordinates: HUQ071 Label: 0
# Coordinates: HUQ090 Label: 2
# Coordinates: IMQ011 Label: 0
# Coordinates: IMQ020 Label: 0
# Coordinates: INQ020 Label: 0
# Coordinates: INQ012 Label: 0
# Coordinates: INQ030 Label: 0
# Coordinates: INQ060 Label: 0
# Coordinates: INQ080 Label: 0
# Coordinates: INQ090 Label: 2
# Coordinates: INQ132 Label: 2
# Coordinates: INQ140 Label: 0
# Coordinates: INQ150 Label: 0
# Coordinates: IND235 Label: 0
# Coordinates: INDFMMPI Label: 0
# Coordinates: INDFMMPC Label: 2
# Coordinates: MCQ010 Label: 0
# Coordinates: MCQ053 Label: 0
# Coordinates: MCQ082 Label: 1
# Coordinates: MCQ086 Label: 0
# Coordinates: MCQ092 Label: 2
# Coordinates: MCQ203 Label: 2
# Coordinates: MCQ300B Label: 1
# Coordinates: OHQ030 Label: 0
# Coordinates: OHQ033 Label: 0
# Coordinates: OHQ770 Label: 0
# Coordinates: OHQ845 Label: 1
# Coordinates: PAAQUEX Label: 0
# Coordinates: SMQ860 Label: 0
# Coordinates: SMQ870 Label: 0
# Coordinates: SMQ872 Label: 1
# Coordinates: SMQ874 Label: 2
# Coordinates: SMQ878 Label: 0
# Coordinates: SMAQUEX.x Label: 0
# Coordinates: clusters Label: 0

# %% [markdown]
# ### Plot your clusters on top of the BMI v. Income Poverty Ratio Plot

# %%
nhanes_scaled['labels'] = kmeans.fit_predict(nhanes_scaled)

# %%
nhanes_scaled['labels'].value_counts()
# Out:
# 0    1278
# 2     569
# 1     217
# Name: labels, dtype: int64

# %%
ax = sns.scatterplot(x = "INDFMPIR", y = "BMXBMI", hue="labels", palette = "tab10", data = nhanes_scaled)
ax.set(xlabel = "Income to Poverty Line Ratio",
      ylabel = "Body Mass Index")
ax.set_title("BMI v. Income-Poverty Ratio")
plt.show()

# %%
## Your Answer Here
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(*nhanes_scaled[kmeans.labels_==0,:].T, s=50, c='r', label='Cluster 0')
ax1.scatter(*nhanes_scaled[kmeans.labels_==1,:].T, s=50, c='b', label='Cluster 1')
ax1.scatter(*nhanes_scaled[kmeans.labels_==2,:].T, s=50, c='g', label='Cluster 2')
ax1.scatter(kmeans.cluster_centers_.T, s=50, marker='+', c='black', label='cluster centers')
plt.legend(loc='upper left')
plt.xlabel('feature0')
plt.ylabel('feature1')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-29063940b3c3> in <module>
#       3 ax1 = fig.add_subplot(111)
#       4
# ----> 5 ax1.scatter(nhanes_scaled[kmeans.labels_==0,:], s=50, c='r', label='Cluster 0')
#       6 ax1.scatter(nhanes_scaled[kmeans.labels_==1,:], s=50, c='b', label='Cluster 1')
#       7 ax1.scatter(nhanes_scaled[kmeans.labels_==2,:], s=50, c='g', label='Cluster 2')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078             casted_key = self._maybe_cast_indexer(key)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#    3082                 raise KeyError(key) from err
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(array([ True, False, False, ..., False,  True, False]), slice(None, None, None))' is an invalid key

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# ### Retrain the clustering algorithm on PCA components and plot clusters on your 2D scatter

# %%
## Your Answer Here
new_points = np.asarray([[0, 4],
                        [19, 25],
                        [40, 50]])

print("Predictions:")
print()

print("0, 4")
print("Cluster:", kmeans.predict([[0, 4]]))
print()

print("19, 25")
print("Cluster:", kmeans.predict([[19, 25]]))
print()

print("40, 50")
print("Cluster:", kmeans.predict([[40, 50]]))

#plot new points

fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(*X[kmeans.labels_==0,:].T, s=50, c='r', label='Cluster 0')
ax1.scatter(*X[kmeans.labels_==1,:].T, s=50, c='b', label='Cluster 1')
ax1.scatter(*X[kmeans.labels_==2,:].T, s=50, c='g', label='Cluster 2')
ax1.scatter(*kmeans.cluster_centers_.T, s=50, c='black', marker='+', label='cluster centers')
ax1.scatter(*new_points.T, s=50, c='cyan', label='new points')
plt.legend(loc='upper left')
plt.xlabel('feature0')
plt.ylabel('feature1')
plt.show()

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# ## Neural Network

# %% [markdown]
# Now we are ready to predict! Do the following:
#
# - Choose either HSD010 or HSD010\_binary as your target outcome.
# - Train a neural network using the original features. Much of the code to train a basic neural net has been set up for you, but you will need to fill in a couple of missing pieces.
# - Train a neural network using only your PCA components as features.
# - Train a neural network using your PCA components and the predicted class membership from your clustering algorithm as features.
# - Compare and contrast how well each algorithm did. Which featurization technique would you pick and why?

# %% [markdown]
# Below we provide a template for training a neural network. Use this template for training on the original features, on the PCA components, and the PCA components + the predicted classes from your clusters.

# %% [markdown]
# ### Neural Network on Original Features

# %%
y = ... # either hsd010 or hsd010_binary
X = ... # drop out any columns that aren't features

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .25, random_state = 10)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
num_classes = ...

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(..., ...)
y_test = keras.utils.to_categorical(..., ...)
num_classes = y_test.shape[1]

# %%
model = Sequential()

model.add(
    Dense(..., input_dim= ..., kernel_initializer= ..., activation= ...)
)

model.add(
    Dense(..., kernel_initializer= ..., activation= ...)
)

## Add any additional layers you wish here

model.compile(loss= ..., optimizer= ..., metrics=[...])

model.fit(..., ..., validation_data=(..., ...), epochs=..., batch_size=..., verbose=...)

# %% [markdown]
# ### Neural Network on Principal Components

# %%
## Your Answer Here

# %% [markdown]
# ### Neural Network on Principal Components + Cluster Membership

# %%
## Your Answer Here

# %% [markdown]
# ## Discussion Questions

# %% [markdown]
# 1. In your own words, what is the difference between PCA and clustering?

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# 2. Did you notice any advantages to combining PCA and clustering? If so, what do you think they were? If not, why do you think you didn't see any gains from this combination?

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# 3. How can unsupervised techniques help with downstream supervised learning tasks when working with "big data?"

# %%
## Your Answer Here
